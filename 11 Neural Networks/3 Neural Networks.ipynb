# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-10, 10, 50)

# %%
plt.plot(x, 1/(1+np.exp(-x)))
plt.plot(x, 1/(1+np.exp(-0.5*x)))
plt.plot(x, 1/(1+np.exp(-10*x)))
